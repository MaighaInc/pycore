# %% [markdown]
# # 📘 P2.1.2.3 – Early AI - The Legacy Era
#
# ## Topic: Search Algorithms & Planning Systems
# ---

# %% [markdown]
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will be able to:
# - Get the idea of **search** (trying options to reach a goal — like maps)
# - Get the idea of **planning** (deciding steps in order — like your daily routine)
# - See how Early AI used both, and why it had limits

# %% [markdown]
# ## 🔍 3. What is Search in Early AI?
#
# **Think of it like this:** You're in a mall and want to find a shop. You try one path, then another, until you reach it. That "trying different paths to reach a goal" is what **search** means in Early AI.
#
# So: **Search = exploring options step-by-step to reach a goal.**
#
# Early AI used this idea for:
# - Finding a route (like maps)
# - Solving puzzles (like mazes)
# - Choosing a good move (like in games)
#
# 💡 **Don't worry:** We're not going to code search algorithms here. Just get the idea — "search" means trying options in a structured way to reach a goal.

# %% [markdown]
# ## 🗺️ 4. What is Planning in Early AI?
#
# **Think of it like this:** Your morning plan — wake up → brush → breakfast → leave. You decide the **order of steps** to reach the goal (reaching office on time). That's **planning**.
#
# So:
# - **Search** = *How do I get there?* (trying paths)
# - **Planning** = *What steps do I take, in what order?* (sequence of actions)
#
# Early AI used planning for things like: robot moving from A to B, scheduling tasks, or deciding moves in a game. Same idea you use every day — just automated.

# %% [markdown]
# ## 🗺 Example: Google Maps (Search in Action)
#
# You use this every day: **Home → College.** Many roads, many turns. The app:
# 1. **Explores** possible routes
# 2. **Compares** them (time, distance)
# 3. **Chooses** the best path
#
# **Algorithms used internally:**
# - Breadth-First Search (BFS)
# - Dijkstra’s Algorithm
# - A* Search
#
# 👉 You don’t need to implement them now.
#
# 👉 Just understand: intelligence came from structured searching

# %% [markdown]
# ## 🧩 Limitations of Early AI (Rule-Based, Search, Planning)
#
# In simple words:
# - When problems get big, rules get messy
# - Systems can't learn or adapt on their own
# - If something unexpected happens, the plan can break
# - More rules = more work to maintain
#
# **So:** Early AI was great for clear, structured problems — but not for messy, changing, or huge ones. That's why AI evolved toward learning from data (Machine Learning).

# %% [markdown]
# ---
# ## 📝 Key Takeaways
#
# - **Search in AI** = exploring options step-by-step to reach a goal (paths, puzzles, best moves). (Think: maps finding a route.)
# - **Planning in AI** = deciding *what sequence of actions* to take to achieve a goal. It often uses search underneath (e.g. robot navigation, scheduling).
# - **Early AI - The Legacy Era** relied on four methods: IF–THEN rules, decision trees (manual), **search**, and **planning**. This notebook covered the last two.
# - **Limitations:** Rule-based + search + planning are powerful for structured problems but don’t scale to uncertainty, huge spaces, or adaptation. That’s why AI evolved toward **Machine Learning** — we’ll see that next in **ML Foundations**.

# %% [markdown]
# ---
# ## 🔎 Optional Exploration: Go Further!
#
# If you want to explore further, search these topics:
# - Breadth First Search (BFS)
# - Depth First Search (DFS)
# - A* Search
# - Dijkstra’s Algorithm
# - Minimax Algorithm
# - STRIPS Planning
#
# Try implementing small versions in Python.
#
# But remember:
# No pressure — our goal is just to see how Early AI worked before learning from data.

# %% [markdown]
# ---
# ## 🎓 Final Message
#
# Understand this clearly:
#
# Early AI tried to create intelligence by:
# - Writing rules
# - Building decision trees
# - Searching possibilities
# - Planning sequences
#
# It was powerful.
# It was logical.
# It was foundational.
#
# But it was not scalable.
#
# That’s why AI evolved.
